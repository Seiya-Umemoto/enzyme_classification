# %%
# !pip3 install Bio
# Out:
# ...
#      |████████████████████████████████| 102kB 2.1MB/s
# ...
#      |████████████████████████████████| 2.3MB 12.0MB/s
# ...

# %%
from Bio import SeqIO
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls "/content/drive/My Drive/ecami"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# datapreprocessing.ipynb  dataset  Untitled0.ipynb

# %%
FULLDATASET = '/content/drive/My Drive/ecami/dataset/ecamidata.fa'
PARTIALDATASET =  '/content/drive/My Drive/ecami/dataset/testdata.fa'

# %%
unique_effects = []

def check_whether_to_append(effects_):
    for element in effects_:
        if element not in unique_effects:
            unique_effects.append(element)

with open(FULLDATASET) as fasta_file:  # Will close handle cleanly
    identifiers = []
    sequences = []
    effects = []
    for seq_record in SeqIO.parse(fasta_file, 'fasta'):  # (generator)
        identifier = seq_record.id.split('|')[0]
        effects_ = seq_record.id.split('|')[1:]
        effects_ = check_whether_to_append(effects_)
        identifiers.append(identifier)
        sequences.append(seq_record.seq.__str__())
        effects.append(effect)

len(unique_effects)
# Out:
# 984
